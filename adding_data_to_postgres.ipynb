# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import psycopg2

# %%
def fetch_candles(product_id, start, end, granularity):
    url = f"https://api.pro.coinbase.com/products/{product_id}/candles"
    params = {
        'start': start,
        'end': end,
        'granularity': granularity
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Failed to fetch data: {response.status_code} {response.text}")

# %%
def append_to_postgres(cur, time, low, high, open, close, volume):
    cur.execute("INSERT INTO eth_2022_2023(time, low, high, open, close, volume) VALUES (%s, %s, %s, %s, %s, %s)",
                (time, low, high, open, close, volume))

# %%
# Database configuration
conn = psycopg2.connect(
    database="ethereum", 
    user="postgres", 
    password="PASSWORD", 
    host="localhost", 
    port="5432"
)
cur = conn.cursor()

# API configuration
product_id = "ETH-USD"
start_date = datetime(2022, 1, 1)  # starting from the beginning of the year
end_date = datetime(2023, 1, 1)  # up to the current time
granularity = 300  # Daily granularity

# Loop through each day and fetch data
current_date = start_date
while current_date < end_date:
    next_date = current_date + timedelta(days=1)
    try:
        daily_data = fetch_candles(product_id, current_date.isoformat() + "Z", next_date.isoformat() + "Z", granularity)
        for entry in daily_data:
            time = datetime.fromtimestamp(entry[0]).isoformat()
            low = entry[1]
            high = entry[2]
            open = entry[3]
            close = entry[4]
            volume = entry[5]
            append_to_postgres(cur, time, low, high, open, close, volume)
        print(f"Fetched and inserted data for {current_date.date()} to {next_date.date()}")
    except Exception as e:
        print(e)
    current_date = next_date

# Commit changes and close connection
conn.commit()
cur.close()
conn.close()

# %%
def save_to_csv(data, filename):
    df = pd.DataFrame(data, columns=['time', 'low', 'high', 'open', 'close', 'volume'])
    df['time'] = pd.to_datetime(df['time'], unit='s')
    df.sort_values('time', ascending=True, inplace=True)  # Ensure data is in chronological order
    df.to_csv(filename, index=False)
    print(f"Data saved to {filename}")

# %%
all_data = []
# Loop through each day and fetch data
current_date = start_date
while current_date < end_date:
    next_date = current_date + timedelta(days=1)
    try:
        daily_data = fetch_candles(product_id, current_date.isoformat() + "Z", next_date.isoformat() + "Z", granularity)
        all_data.extend(daily_data)
        print(f"Fetched data for {current_date.date()} to {next_date.date()}")
    except Exception as e:
        print(e)
    current_date = next_date

# Save all fetched data to CSV
save_to_csv(all_data, 'eth_2022_2023.csv')
# Out:
# Fetched data for 2022-01-01 to 2022-01-02
# Fetched data for 2022-01-02 to 2022-01-03
# Fetched data for 2022-01-03 to 2022-01-04
# Fetched data for 2022-01-04 to 2022-01-05
# Fetched data for 2022-01-05 to 2022-01-06
# Fetched data for 2022-01-06 to 2022-01-07
# Fetched data for 2022-01-07 to 2022-01-08
# Fetched data for 2022-01-08 to 2022-01-09
# Fetched data for 2022-01-09 to 2022-01-10
# Fetched data for 2022-01-10 to 2022-01-11
# Fetched data for 2022-01-11 to 2022-01-12
# Fetched data for 2022-01-12 to 2022-01-13
# Fetched data for 2022-01-13 to 2022-01-14
# Fetched data for 2022-01-14 to 2022-01-15
# Fetched data for 2022-01-15 to 2022-01-16
# Fetched data for 2022-01-16 to 2022-01-17
# Fetched data for 2022-01-17 to 2022-01-18
# Fetched data for 2022-01-18 to 2022-01-19
# Fetched data for 2022-01-19 to 2022-01-20
# Fetched data for 2022-01-20 to 2022-01-21
# Fetched data for 2022-01-21 to 2022-01-22
# Fetched data for 2022-01-22 to 2022-01-23
# Fetched data for 2022-01-23 to 2022-01-24
# Fetched data for 2022-01-24 to 2022-01-25
# Fetched data for 2022-01-25 to 2022-01-26
# Fetched data for 2022-01-26 to 2022-01-27
# Fetched data for 2022-01-27 to 2022-01-28
# Fetched data for 2022-01-28 to 2022-01-29
# Fetched data for 2022-01-29 to 2022-01-30
# Fetched data for 2022-01-30 to 2022-01-31
# Fetched data for 2022-01-31 to 2022-02-01
# Fetched data for 2022-02-01 to 2022-02-02
# Fetched data for 2022-02-02 to 2022-02-03
# Fetched data for 2022-02-03 to 2022-02-04
# Fetched data for 2022-02-04 to 2022-02-05
# Fetched data for 2022-02-05 to 2022-02-06
# Fetched data for 2022-02-06 to 2022-02-07
# Fetched data for 2022-02-07 to 2022-02-08
# Fetched data for 2022-02-08 to 2022-02-09
# Fetched data for 2022-02-09 to 2022-02-10
# Fetched data for 2022-02-10 to 2022-02-11
# Fetched data for 2022-02-11 to 2022-02-12
# Fetched data for 2022-02-12 to 2022-02-13
# Fetched data for 2022-02-13 to 2022-02-14
# Fetched data for 2022-02-14 to 2022-02-15
# Fetched data for 2022-02-15 to 2022-02-16
# Fetched data for 2022-02-16 to 2022-02-17
# Fetched data for 2022-02-17 to 2022-02-18
# Fetched data for 2022-02-18 to 2022-02-19
# Fetched data for 2022-02-19 to 2022-02-20
# Fetched data for 2022-02-20 to 2022-02-21
# Fetched data for 2022-02-21 to 2022-02-22
# Fetched data for 2022-02-22 to 2022-02-23
# Fetched data for 2022-02-23 to 2022-02-24
# Fetched data for 2022-02-24 to 2022-02-25
# Fetched data for 2022-02-25 to 2022-02-26
# Fetched data for 2022-02-26 to 2022-02-27
# Fetched data for 2022-02-27 to 2022-02-28
# Fetched data for 2022-02-28 to 2022-03-01
# Fetched data for 2022-03-01 to 2022-03-02
# Fetched data for 2022-03-02 to 2022-03-03
# Fetched data for 2022-03-03 to 2022-03-04
# Fetched data for 2022-03-04 to 2022-03-05
# Fetched data for 2022-03-05 to 2022-03-06
# Fetched data for 2022-03-06 to 2022-03-07
# Fetched data for 2022-03-07 to 2022-03-08
# Fetched data for 2022-03-08 to 2022-03-09
# Fetched data for 2022-03-09 to 2022-03-10
# Fetched data for 2022-03-10 to 2022-03-11
# Fetched data for 2022-03-11 to 2022-03-12
# Fetched data for 2022-03-12 to 2022-03-13
# Fetched data for 2022-03-13 to 2022-03-14
# Fetched data for 2022-03-14 to 2022-03-15
# Fetched data for 2022-03-15 to 2022-03-16
# Fetched data for 2022-03-16 to 2022-03-17
# Fetched data for 2022-03-17 to 2022-03-18
# Fetched data for 2022-03-18 to 2022-03-19
# Fetched data for 2022-03-19 to 2022-03-20
# Fetched data for 2022-03-20 to 2022-03-21
# Fetched data for 2022-03-21 to 2022-03-22
# Fetched data for 2022-03-22 to 2022-03-23
# Fetched data for 2022-03-23 to 2022-03-24
# Fetched data for 2022-03-24 to 2022-03-25
# Fetched data for 2022-03-25 to 2022-03-26
# Fetched data for 2022-03-26 to 2022-03-27
# Fetched data for 2022-03-27 to 2022-03-28
# Fetched data for 2022-03-28 to 2022-03-29
# Fetched data for 2022-03-29 to 2022-03-30
# Fetched data for 2022-03-30 to 2022-03-31
# Fetched data for 2022-03-31 to 2022-04-01
# Fetched data for 2022-04-01 to 2022-04-02
# Fetched data for 2022-04-02 to 2022-04-03
# Fetched data for 2022-04-03 to 2022-04-04
# Fetched data for 2022-04-04 to 2022-04-05
# Fetched data for 2022-04-05 to 2022-04-06
# Fetched data for 2022-04-06 to 2022-04-07
# Fetched data for 2022-04-07 to 2022-04-08
# Fetched data for 2022-04-08 to 2022-04-09
# Fetched data for 2022-04-09 to 2022-04-10
# Fetched data for 2022-04-10 to 2022-04-11
# Fetched data for 2022-04-11 to 2022-04-12
# Fetched data for 2022-04-12 to 2022-04-13
# Fetched data for 2022-04-13 to 2022-04-14
# Fetched data for 2022-04-14 to 2022-04-15
# Fetched data for 2022-04-15 to 2022-04-16
# Fetched data for 2022-04-16 to 2022-04-17
# Fetched data for 2022-04-17 to 2022-04-18
# Fetched data for 2022-04-18 to 2022-04-19
# Fetched data for 2022-04-19 to 2022-04-20
# Fetched data for 2022-04-20 to 2022-04-21
# Fetched data for 2022-04-21 to 2022-04-22
# Fetched data for 2022-04-22 to 2022-04-23
# Fetched data for 2022-04-23 to 2022-04-24
# Fetched data for 2022-04-24 to 2022-04-25
# Fetched data for 2022-04-25 to 2022-04-26
# Fetched data for 2022-04-26 to 2022-04-27
# Fetched data for 2022-04-27 to 2022-04-28
# Fetched data for 2022-04-28 to 2022-04-29
# Fetched data for 2022-04-29 to 2022-04-30
# Fetched data for 2022-04-30 to 2022-05-01
# Fetched data for 2022-05-01 to 2022-05-02
# Fetched data for 2022-05-02 to 2022-05-03
# Fetched data for 2022-05-03 to 2022-05-04
# Fetched data for 2022-05-04 to 2022-05-05
# Fetched data for 2022-05-05 to 2022-05-06
# Fetched data for 2022-05-06 to 2022-05-07
# Fetched data for 2022-05-07 to 2022-05-08
# Fetched data for 2022-05-08 to 2022-05-09
# Fetched data for 2022-05-09 to 2022-05-10
# Fetched data for 2022-05-10 to 2022-05-11
# Fetched data for 2022-05-11 to 2022-05-12
# Fetched data for 2022-05-12 to 2022-05-13
# Fetched data for 2022-05-13 to 2022-05-14
# Fetched data for 2022-05-14 to 2022-05-15
# Fetched data for 2022-05-15 to 2022-05-16
# Fetched data for 2022-05-16 to 2022-05-17
# Fetched data for 2022-05-17 to 2022-05-18
# Fetched data for 2022-05-18 to 2022-05-19
# Fetched data for 2022-05-19 to 2022-05-20
# Fetched data for 2022-05-20 to 2022-05-21
# Fetched data for 2022-05-21 to 2022-05-22
# Fetched data for 2022-05-22 to 2022-05-23
# Fetched data for 2022-05-23 to 2022-05-24
# Fetched data for 2022-05-24 to 2022-05-25
# Fetched data for 2022-05-25 to 2022-05-26
# Fetched data for 2022-05-26 to 2022-05-27
# Fetched data for 2022-05-27 to 2022-05-28
# Fetched data for 2022-05-28 to 2022-05-29
# Fetched data for 2022-05-29 to 2022-05-30
# Fetched data for 2022-05-30 to 2022-05-31
# Fetched data for 2022-05-31 to 2022-06-01
# Fetched data for 2022-06-01 to 2022-06-02
# Fetched data for 2022-06-02 to 2022-06-03
# Fetched data for 2022-06-03 to 2022-06-04
# Fetched data for 2022-06-04 to 2022-06-05
# Fetched data for 2022-06-05 to 2022-06-06
# Fetched data for 2022-06-06 to 2022-06-07
# Fetched data for 2022-06-07 to 2022-06-08
# Fetched data for 2022-06-08 to 2022-06-09
# Fetched data for 2022-06-09 to 2022-06-10
# Fetched data for 2022-06-10 to 2022-06-11
# Fetched data for 2022-06-11 to 2022-06-12
# Fetched data for 2022-06-12 to 2022-06-13
# Fetched data for 2022-06-13 to 2022-06-14
# Fetched data for 2022-06-14 to 2022-06-15
# Fetched data for 2022-06-15 to 2022-06-16
# Fetched data for 2022-06-16 to 2022-06-17
# Fetched data for 2022-06-17 to 2022-06-18
# Fetched data for 2022-06-18 to 2022-06-19
# Fetched data for 2022-06-19 to 2022-06-20
# Fetched data for 2022-06-20 to 2022-06-21
# Fetched data for 2022-06-21 to 2022-06-22
# Fetched data for 2022-06-22 to 2022-06-23
# Fetched data for 2022-06-23 to 2022-06-24
# Fetched data for 2022-06-24 to 2022-06-25
# Fetched data for 2022-06-25 to 2022-06-26
# Fetched data for 2022-06-26 to 2022-06-27
# Fetched data for 2022-06-27 to 2022-06-28
# Fetched data for 2022-06-28 to 2022-06-29
# Fetched data for 2022-06-29 to 2022-06-30
# Fetched data for 2022-06-30 to 2022-07-01
# Fetched data for 2022-07-01 to 2022-07-02
# Fetched data for 2022-07-02 to 2022-07-03
# Fetched data for 2022-07-03 to 2022-07-04
# Fetched data for 2022-07-04 to 2022-07-05
# Fetched data for 2022-07-05 to 2022-07-06
# Fetched data for 2022-07-06 to 2022-07-07
# Fetched data for 2022-07-07 to 2022-07-08
# Fetched data for 2022-07-08 to 2022-07-09
# Fetched data for 2022-07-09 to 2022-07-10
# Fetched data for 2022-07-10 to 2022-07-11
# Fetched data for 2022-07-11 to 2022-07-12
# Fetched data for 2022-07-12 to 2022-07-13
# Fetched data for 2022-07-13 to 2022-07-14
# Fetched data for 2022-07-14 to 2022-07-15
# Fetched data for 2022-07-15 to 2022-07-16
# Fetched data for 2022-07-16 to 2022-07-17
# Fetched data for 2022-07-17 to 2022-07-18
# Fetched data for 2022-07-18 to 2022-07-19
# Fetched data for 2022-07-19 to 2022-07-20
# Fetched data for 2022-07-20 to 2022-07-21
# Fetched data for 2022-07-21 to 2022-07-22
# Fetched data for 2022-07-22 to 2022-07-23
# Fetched data for 2022-07-23 to 2022-07-24
# Fetched data for 2022-07-24 to 2022-07-25
# Fetched data for 2022-07-25 to 2022-07-26
# Fetched data for 2022-07-26 to 2022-07-27
# Fetched data for 2022-07-27 to 2022-07-28
# Fetched data for 2022-07-28 to 2022-07-29
# Fetched data for 2022-07-29 to 2022-07-30
# Fetched data for 2022-07-30 to 2022-07-31
# Fetched data for 2022-07-31 to 2022-08-01
# Fetched data for 2022-08-01 to 2022-08-02
# Fetched data for 2022-08-02 to 2022-08-03
# Fetched data for 2022-08-03 to 2022-08-04
# Fetched data for 2022-08-04 to 2022-08-05
# Fetched data for 2022-08-05 to 2022-08-06
# Fetched data for 2022-08-06 to 2022-08-07
# Fetched data for 2022-08-07 to 2022-08-08
# Fetched data for 2022-08-08 to 2022-08-09
# Fetched data for 2022-08-09 to 2022-08-10
# Fetched data for 2022-08-10 to 2022-08-11
# Fetched data for 2022-08-11 to 2022-08-12
# Fetched data for 2022-08-12 to 2022-08-13
# Fetched data for 2022-08-13 to 2022-08-14
# Fetched data for 2022-08-14 to 2022-08-15
# Fetched data for 2022-08-15 to 2022-08-16
# Fetched data for 2022-08-16 to 2022-08-17
# Fetched data for 2022-08-17 to 2022-08-18
# Fetched data for 2022-08-18 to 2022-08-19
# Fetched data for 2022-08-19 to 2022-08-20
# Fetched data for 2022-08-20 to 2022-08-21
# Fetched data for 2022-08-21 to 2022-08-22
# Fetched data for 2022-08-22 to 2022-08-23
# Fetched data for 2022-08-23 to 2022-08-24
# Fetched data for 2022-08-24 to 2022-08-25
# Fetched data for 2022-08-25 to 2022-08-26
# Fetched data for 2022-08-26 to 2022-08-27
# Fetched data for 2022-08-27 to 2022-08-28
# Fetched data for 2022-08-28 to 2022-08-29
# Fetched data for 2022-08-29 to 2022-08-30
# Fetched data for 2022-08-30 to 2022-08-31
# Fetched data for 2022-08-31 to 2022-09-01
# Fetched data for 2022-09-01 to 2022-09-02
# Fetched data for 2022-09-02 to 2022-09-03
# Fetched data for 2022-09-03 to 2022-09-04
# Fetched data for 2022-09-04 to 2022-09-05
# Fetched data for 2022-09-05 to 2022-09-06
# Fetched data for 2022-09-06 to 2022-09-07
# Fetched data for 2022-09-07 to 2022-09-08
# Fetched data for 2022-09-08 to 2022-09-09
# Fetched data for 2022-09-09 to 2022-09-10
# Fetched data for 2022-09-10 to 2022-09-11
# Fetched data for 2022-09-11 to 2022-09-12
# Fetched data for 2022-09-12 to 2022-09-13
# Fetched data for 2022-09-13 to 2022-09-14
# Fetched data for 2022-09-14 to 2022-09-15
# Fetched data for 2022-09-15 to 2022-09-16
# Fetched data for 2022-09-16 to 2022-09-17
# Fetched data for 2022-09-17 to 2022-09-18
# Fetched data for 2022-09-18 to 2022-09-19
# Fetched data for 2022-09-19 to 2022-09-20
# Fetched data for 2022-09-20 to 2022-09-21
# Fetched data for 2022-09-21 to 2022-09-22
# Fetched data for 2022-09-22 to 2022-09-23
# Fetched data for 2022-09-23 to 2022-09-24
# Fetched data for 2022-09-24 to 2022-09-25
# Fetched data for 2022-09-25 to 2022-09-26
# Fetched data for 2022-09-26 to 2022-09-27
# Fetched data for 2022-09-27 to 2022-09-28
# Fetched data for 2022-09-28 to 2022-09-29
# Fetched data for 2022-09-29 to 2022-09-30
# Fetched data for 2022-09-30 to 2022-10-01
# Fetched data for 2022-10-01 to 2022-10-02
# Fetched data for 2022-10-02 to 2022-10-03
# Fetched data for 2022-10-03 to 2022-10-04
# Fetched data for 2022-10-04 to 2022-10-05
# Fetched data for 2022-10-05 to 2022-10-06
# Fetched data for 2022-10-06 to 2022-10-07
# Fetched data for 2022-10-07 to 2022-10-08
# Fetched data for 2022-10-08 to 2022-10-09
# Fetched data for 2022-10-09 to 2022-10-10
# Fetched data for 2022-10-10 to 2022-10-11
# Fetched data for 2022-10-11 to 2022-10-12
# Fetched data for 2022-10-12 to 2022-10-13
# Fetched data for 2022-10-13 to 2022-10-14
# Fetched data for 2022-10-14 to 2022-10-15
# Fetched data for 2022-10-15 to 2022-10-16
# Fetched data for 2022-10-16 to 2022-10-17
# Fetched data for 2022-10-17 to 2022-10-18
# Fetched data for 2022-10-18 to 2022-10-19
# Fetched data for 2022-10-19 to 2022-10-20
# Fetched data for 2022-10-20 to 2022-10-21
# Fetched data for 2022-10-21 to 2022-10-22
# Fetched data for 2022-10-22 to 2022-10-23
# Fetched data for 2022-10-23 to 2022-10-24
# Fetched data for 2022-10-24 to 2022-10-25
# Fetched data for 2022-10-25 to 2022-10-26
# Fetched data for 2022-10-26 to 2022-10-27
# Fetched data for 2022-10-27 to 2022-10-28
# Fetched data for 2022-10-28 to 2022-10-29
# Fetched data for 2022-10-29 to 2022-10-30
# Fetched data for 2022-10-30 to 2022-10-31
# Fetched data for 2022-10-31 to 2022-11-01
# Fetched data for 2022-11-01 to 2022-11-02
# Fetched data for 2022-11-02 to 2022-11-03
# Fetched data for 2022-11-03 to 2022-11-04
# Fetched data for 2022-11-04 to 2022-11-05
# Fetched data for 2022-11-05 to 2022-11-06
# Fetched data for 2022-11-06 to 2022-11-07
# Fetched data for 2022-11-07 to 2022-11-08
# Fetched data for 2022-11-08 to 2022-11-09
# Fetched data for 2022-11-09 to 2022-11-10
# Fetched data for 2022-11-10 to 2022-11-11
# Fetched data for 2022-11-11 to 2022-11-12
# Fetched data for 2022-11-12 to 2022-11-13
# Fetched data for 2022-11-13 to 2022-11-14
# Fetched data for 2022-11-14 to 2022-11-15
# Fetched data for 2022-11-15 to 2022-11-16
# Fetched data for 2022-11-16 to 2022-11-17
# Fetched data for 2022-11-17 to 2022-11-18
# Fetched data for 2022-11-18 to 2022-11-19
# Fetched data for 2022-11-19 to 2022-11-20
# Fetched data for 2022-11-20 to 2022-11-21
# Fetched data for 2022-11-21 to 2022-11-22
# Fetched data for 2022-11-22 to 2022-11-23
# Fetched data for 2022-11-23 to 2022-11-24
# Fetched data for 2022-11-24 to 2022-11-25
# Fetched data for 2022-11-25 to 2022-11-26
# Fetched data for 2022-11-26 to 2022-11-27
# Fetched data for 2022-11-27 to 2022-11-28
# Fetched data for 2022-11-28 to 2022-11-29
# Fetched data for 2022-11-29 to 2022-11-30
# Fetched data for 2022-11-30 to 2022-12-01
# Fetched data for 2022-12-01 to 2022-12-02
# Fetched data for 2022-12-02 to 2022-12-03
# Fetched data for 2022-12-03 to 2022-12-04
# Fetched data for 2022-12-04 to 2022-12-05
# Fetched data for 2022-12-05 to 2022-12-06
# Fetched data for 2022-12-06 to 2022-12-07
# Fetched data for 2022-12-07 to 2022-12-08
# Fetched data for 2022-12-08 to 2022-12-09
# Fetched data for 2022-12-09 to 2022-12-10
# Fetched data for 2022-12-10 to 2022-12-11
# Fetched data for 2022-12-11 to 2022-12-12
# Fetched data for 2022-12-12 to 2022-12-13
# Fetched data for 2022-12-13 to 2022-12-14
# Fetched data for 2022-12-14 to 2022-12-15
# Fetched data for 2022-12-15 to 2022-12-16
# Fetched data for 2022-12-16 to 2022-12-17
# Fetched data for 2022-12-17 to 2022-12-18
# Fetched data for 2022-12-18 to 2022-12-19
# Fetched data for 2022-12-19 to 2022-12-20
# Fetched data for 2022-12-20 to 2022-12-21
# Fetched data for 2022-12-21 to 2022-12-22
# Fetched data for 2022-12-22 to 2022-12-23
# Fetched data for 2022-12-23 to 2022-12-24
# Fetched data for 2022-12-24 to 2022-12-25
# Fetched data for 2022-12-25 to 2022-12-26
# Fetched data for 2022-12-26 to 2022-12-27
# Fetched data for 2022-12-27 to 2022-12-28
# Fetched data for 2022-12-28 to 2022-12-29
# Fetched data for 2022-12-29 to 2022-12-30
# Fetched data for 2022-12-30 to 2022-12-31
# Fetched data for 2022-12-31 to 2023-01-01
# Data saved to eth_2022_2023.csv
